# %% [markdown]
# # exploraatory data analysis
#
# understanding the data to explore how the dta is represent in the data base and if there is a neeed of creating some aggregated tables that can help with :
#
# * vendor selection for profitability
# * product pricing optimization

# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
# crating database connection
conn = create_engine('postgresql+psycopg2://postgres:root@localhost:5432/vendor_db')

# %%
tables = pd.read_sql_query(
    "SELECT table_name FROM information_schema.tables WHERE table_schema='public';",
    con=conn
)
tables.head(5)
# Out:
#              table_name
# 0  vendor_sales_summary
# 1         end_inventory
# 2             purchases
# 3       purchase_prices
# 4                 sales

# %%
pd.read_sql_query("SELECT * FROM sales LIMIT 5;", con=conn)
# Out:
#            InventoryId  Store  Brand                 Description        Size  \
# 0  1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses       750mL
# 1  1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses       750mL
# 2  1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses       750mL
# 3  1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses       750mL
# 4  1_HARDERSFIELD_1005      1   1005     Maker's Mark Combo Pack  375mL 2 Pk
#
#    SalesQuantity  SalesDollars  SalesPrice   SalesDate  Volume  \
# 0              1         16.49       16.49  2024-01-01   750.0
# 1              2         32.98       16.49  2024-01-02   750.0
# 2              1         16.49       16.49  2024-01-03   750.0
# 3              1         14.49       14.49  2024-01-08   750.0
# 4              2         69.98       34.99  2024-01-09   375.0
#
#    Classification  ExciseTax  VendorNo                   VendorName
# ...

# %%
pd.read_sql_query("SELECT count(*) from purchases;", con=conn)
# Out:
#      count
# 0  2372474

# %%
for table in tables['table_name']:
    print('-'*50, f'{table}', '-'*50)
    print('count of records:', pd.read_sql_query(f"SELECT count(*) as count FROM {table};", con=conn).iloc[0, 0])
    display(pd.read_sql_query(f"SELECT * FROM {table} LIMIT 5", con=conn))
# Out:
# -------------------------------------------------- vendor_sales_summary --------------------------------------------------
# count of records: 10692
#    VendorNumber                VendorName  Brand              Description  \
# 0          1128         BROWN-FORMAN CORP   1233  Jack Daniels No 7 Black
# 1          4425     MARTIGNETTI COMPANIES   3405    Tito's Handmade Vodka
# 2         17035         PERNOD RICARD USA   8068         Absolut 80 Proof
# 3          3960  DIAGEO NORTH AMERICA INC   4261   Capt Morgan Spiced Rum
# 4          3960  DIAGEO NORTH AMERICA INC   3545          Ketel One Vodka
#
#    PurchasePrice  actualprice  Volume  totalpurchasequantity  \
# 0          26.27        36.99  1750.0               145080.0
# 1          23.19        28.99  1750.0               164038.0
# 2          18.24        24.99  1750.0               187407.0
# 3          16.17        22.99  1750.0               201682.0
# 4          21.89        29.99  1750.0               138109.0
#
# ...

# %%
purchases = pd.read_sql_query('SELECT * FROM purchases WHERE "VendorNumber"=4466;', con=conn)
purchases
# Out:
#               InventoryId  Store  Brand                   Description   Size  \
# 0        30_CULCHETH_5255     30   5255  TGI Fridays Ultimte Mudslide  1.75L
# 1       34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced  1.75L
# 2     1_HARDERSFIELD_5255      1   5255  TGI Fridays Ultimte Mudslide  1.75L
# 3       38_GOULCREST_5215     38   5215  TGI Fridays Long Island Iced  1.75L
# 4     59_CLAETHORPES_5215     59   5215  TGI Fridays Long Island Iced  1.75L
# ...                   ...    ...    ...                           ...    ...
# 2187     81_PEMBROKE_5215     81   5215  TGI Fridays Long Island Iced  1.75L
# 2188   62_KILMARNOCK_5255     62   5255  TGI Fridays Ultimte Mudslide  1.75L
# 2189    34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced  1.75L
# 2190     6_GOULCREST_5215      6   5215  TGI Fridays Long Island Iced  1.75L
# 2191    35_HALIVAARA_5255     35   5255  TGI Fridays Ultimte Mudslide  1.75L
#
# ...

# %%
purchases_prices = pd.read_sql_query('SELECT * FROM purchases WHERE "VendorNumber"=4466;', con=conn)
purchases_prices
# Out:
#               InventoryId  Store  Brand                   Description   Size  \
# 0        30_CULCHETH_5255     30   5255  TGI Fridays Ultimte Mudslide  1.75L
# 1       34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced  1.75L
# 2     1_HARDERSFIELD_5255      1   5255  TGI Fridays Ultimte Mudslide  1.75L
# 3       38_GOULCREST_5215     38   5215  TGI Fridays Long Island Iced  1.75L
# 4     59_CLAETHORPES_5215     59   5215  TGI Fridays Long Island Iced  1.75L
# ...                   ...    ...    ...                           ...    ...
# 2187     81_PEMBROKE_5215     81   5215  TGI Fridays Long Island Iced  1.75L
# 2188   62_KILMARNOCK_5255     62   5255  TGI Fridays Ultimte Mudslide  1.75L
# 2189    34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced  1.75L
# 2190     6_GOULCREST_5215      6   5215  TGI Fridays Long Island Iced  1.75L
# 2191    35_HALIVAARA_5255     35   5255  TGI Fridays Ultimte Mudslide  1.75L
#
# ...

# %%
purchases.groupby(['Brand', 'PurchasePrice'])[['Quantity', 'Dollars']].sum()
# Out:
#                      Quantity   Dollars
# Brand PurchasePrice
# 3140  11.19              4640  51921.60
# 5215  9.41               4923  46325.43
# 5255  9.35               6215  58110.25

# %%
purchases_prices
# Out:
#               InventoryId  Store  Brand                   Description   Size  \
# 0        30_CULCHETH_5255     30   5255  TGI Fridays Ultimte Mudslide  1.75L
# 1       34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced  1.75L
# 2     1_HARDERSFIELD_5255      1   5255  TGI Fridays Ultimte Mudslide  1.75L
# 3       38_GOULCREST_5215     38   5215  TGI Fridays Long Island Iced  1.75L
# 4     59_CLAETHORPES_5215     59   5215  TGI Fridays Long Island Iced  1.75L
# ...                   ...    ...    ...                           ...    ...
# 2187     81_PEMBROKE_5215     81   5215  TGI Fridays Long Island Iced  1.75L
# 2188   62_KILMARNOCK_5255     62   5255  TGI Fridays Ultimte Mudslide  1.75L
# 2189    34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced  1.75L
# 2190     6_GOULCREST_5215      6   5215  TGI Fridays Long Island Iced  1.75L
# 2191    35_HALIVAARA_5255     35   5255  TGI Fridays Ultimte Mudslide  1.75L
#
# ...

# %%
purchases['PONumber'].nunique()
# Out:
# 55

# %%
sales = pd.read_sql_query('SELECT * FROM sales;', con=conn)
sales.groupby(['Brand', 'SalesPrice'])[['SalesQuantity', 'SalesDollars']].sum()
# Out:
#                   SalesQuantity  SalesDollars
# Brand SalesPrice
# 58    10.99                 711       7813.89
#       12.99                2735      35527.65
# 60    9.99                  791       7902.09
#       10.99                 984      10814.16
# 61    13.99                 312       4364.88
# ...                         ...           ...
# 90089 119.99                159      19078.41
# 90090 649.99                 15       9749.85
# 90604 119.99                 76       9119.24
# 90609 24.99                  83       2074.17
# 90631 18.99                1659      31504.41
#
# [19921 rows x 2 columns]

# %%
# load the vendor_invoice table and display its columns
vendor_invoice = pd.read_sql_query('SELECT * FROM vendor_invoice;', con=conn)
vendor_invoice.columns
# Out:
# Index(['VendorNumber', 'VendorName', 'InvoiceDate', 'PONumber', 'PODate',
#        'PayDate', 'Quantity', 'Dollars', 'Freight', 'Approval'],
#       dtype='object')

# %%
# load the ccolumn of purchase_prices 
purchase_prices = pd.read_sql_query('SELECT "VendorNumber", "Brand", "PurchasePrice" FROM purchases;', con=conn)

# %%
purchase_prices.columns
# Out:
# Index(['VendorNumber', 'Brand', 'PurchasePrice'], dtype='object')

# %%
purchases.columns
# Out:
# Index(['InventoryId', 'Store', 'Brand', 'Description', 'Size', 'VendorNumber',
#        'VendorName', 'PONumber', 'PODate', 'ReceivingDate', 'InvoiceDate',
#        'PayDate', 'PurchasePrice', 'Quantity', 'Dollars', 'Classification'],
#       dtype='object')

# %%
freight_summary = pd.read_sql_query("""
    SELECT "VendorNumber",
           SUM("Freight") AS Freightcost
      FROM vendor_invoice
     GROUP BY "VendorNumber";
""", con=conn)
freight_summary
# Out:
#      VendorNumber  freightcost
# 0            7255       648.71
# 1            1439         0.27
# 2            9751        24.53
# 3            6830       360.29
# 4            1587      6070.09
# ..            ...          ...
# 121          9625      1933.19
# 122          7154       432.37
# 123          1392     79528.99
# 124          1189       609.39
# 125         90017        80.03
#
# [126 rows x 2 columns]

# %%
pd.read_sql_query("""
    SELECT 
        p."VendorNumber",
        p."VendorName",
        p."Brand",
        p."PurchasePrice",
        
        SUM(p."Quantity") AS totalpurchasequantity,
        SUM(p."Dollars") AS totalpurchasedollars
    FROM purchases p
    JOIN purchase_prices pp
        ON p."Brand" = pp."Brand"
    WHERE p."PurchasePrice" > 0
    GROUP BY p."VendorNumber", p."VendorName", p."Brand", p."PurchasePrice"
    ORDER BY totalpurchasedollars 
""", con=conn)
# Out:
#        VendorNumber                   VendorName  Brand  PurchasePrice  \
# 0              7245  PROXIMO SPIRITS INC.          3065           0.71
# 1              3960  DIAGEO NORTH AMERICA INC      6127           1.47
# 2              3924  HEAVEN HILL DISTILLERIES      9123           0.74
# 3              8004  SAZERAC CO INC                5683           0.39
# 4              9815  WINE GROUP INC                8527           1.32
# ...             ...                          ...    ...            ...
# 10687          3960  DIAGEO NORTH AMERICA INC      3545          21.89
# 10688          3960  DIAGEO NORTH AMERICA INC      4261          16.17
# 10689         17035  PERNOD RICARD USA             8068          18.24
# 10690          4425        MARTIGNETTI COMPANIES   3405          23.19
# 10691          1128  BROWN-FORMAN CORP             1233          26.27
#
#        totalpurchasequantity  totalpurchasedollars
# 0                        1.0                  0.71
# ...

# %%
sales.columns
# Out:
# Index(['InventoryId', 'Store', 'Brand', 'Description', 'Size', 'SalesQuantity',
#        'SalesDollars', 'SalesPrice', 'SalesDate', 'Volume', 'Classification',
#        'ExciseTax', 'VendorNo', 'VendorName'],
#       dtype='object')

# %%
pd.read_sql_query("""
    SELECT 
        s."VendorNo",
        s."VendorName",
        s."Brand",
        s."SalesPrice",
        SUM(s."SalesPrice") AS totalsalesprices,
        SUM(s."SalesDollars") AS totalsalesdollars,
        SUM(s."SalesQuantity") AS totalsalesquantity,
        SUM(s."ExciseTax") AS totalexcisetax
    FROM sales s
    WHERE s."SalesPrice" > 0 AND s."SalesDollars" > 0
    GROUP BY s."VendorNo", s."VendorName", s."Brand", s."SalesPrice"
    ORDER BY totalsalesdollars DESC
""", con=conn)
# Out:
#        VendorNo                   VendorName  Brand  SalesPrice  \
# 0          1128  BROWN-FORMAN CORP             1233       34.99
# 1          3960  DIAGEO NORTH AMERICA INC      3545       29.99
# 2         17035  PERNOD RICARD USA             8068       23.49
# 3          4425        MARTIGNETTI COMPANIES   3405       29.99
# 4          3960  DIAGEO NORTH AMERICA INC      4261       22.99
# ...         ...                          ...    ...         ...
# 19955     10050  Russian Standard Vodka        3623        0.99
# 19956      3924  HEAVEN HILL DISTILLERIES      9123        0.99
# 19957      3252  E & J GALLO WINERY            3933        0.99
# 19958      9206  PHILLIPS PRODUCTS CO.         2773        0.99
# 19959      8004  SAZERAC CO INC                5287        0.49
#
#        totalsalesprices  totalsalesdollars  totalsalesquantity  totalexcisetax
# 0             286498.12         2857178.43             81657.0       150037.64
# ...

# %%
# import time 
# start = time.time()
# final_table= pd.read_sql_query("""
#     SELECT 
#         p."VendorNumber",
#         p."VendorName",
#         p."Brand",
#         p."PurchasePrice",
#         SUM(p."Quantity") AS totalpurchasequantity,
#         SUM(p."Dollars") AS totalpurchasedollars,
#         s."SalesPrice",
#         SUM(s."SalesDollars") AS totalsalesdollars,
#         SUM(s."SalesQuantity") AS totalsalesquantity,
#         SUM(s."ExciseTax") AS totalexcisetax
#     FROM purchases p
#     JOIN purchase_prices pp
#         ON p."Brand" = pp."Brand"
#     JOIN sales s
#         ON p."Brand" = s."Brand"
#     WHERE p."PurchasePrice" > 0 AND s."SalesPrice" > 0
#     GROUP BY p."VendorNumber", p."VendorName", p."Brand", p."PurchasePrice", s."SalesPrice"
#     ORDER BY totalpurchasedollars DESC
# """, con=conn)
# end = time.time()


# import time 
# start = time.time()

# final_table = pd.read_sql_query("""
#     SELECT 
#         pp."VendorNumber",
#         pp."Brand",
#         pp."Price" AS ActualPrice,
#         pp."PurchasePrice",
#         SUM(s."SalesQuantity") AS TotalSalesQuantity,
#         SUM(s."SalesDollars") AS TotalSalesDollars,
#         SUM(s."SalesPrice") AS TotalSalesPrice,
#         SUM(s."ExciseTax") AS TotalExciseTax,
#         SUM(vi."Quantity") AS TotalPurchaseQuantity,
#         SUM(vi."Dollars") AS TotalPurchaseDollars,
#         SUM(vi."Freight") AS TotalFreightCost
#     FROM purchase_prices pp
#     JOIN sales s
#         ON pp."VendorNumber" = s."VendorNo"
#         AND pp."Brand" = s."Brand"
#     JOIN vendor_invoice vi
#         ON pp."VendorNumber" = vi."VendorNumber"
#     GROUP BY pp."VendorNumber", pp."Brand", pp."Price", pp."PurchasePrice"
# """, con=conn)

# end = time.time()

vendor_sales_summary = pd.read_sql_query("""
WITH FreightSummary AS (
    SELECT
        "VendorNumber",
        SUM("Freight") AS FreightCost
    FROM vendor_invoice
    GROUP BY "VendorNumber"
),
PurchaseSummary AS (
    SELECT
        p."VendorNumber",
        p."VendorName",
        p."Brand",
        p."Description",
        p."PurchasePrice",
        pp."Price" AS ActualPrice,
        pp."Volume",
        SUM(p."Quantity") AS TotalPurchaseQuantity,
        SUM(p."Dollars") AS TotalPurchaseDollars
    FROM purchases p
    JOIN purchase_prices pp
        ON p."Brand" = pp."Brand"
    WHERE p."PurchasePrice" > 0
    GROUP BY 
        p."VendorNumber", p."VendorName", p."Brand", p."Description",
        p."PurchasePrice", pp."Price", pp."Volume"
),
SalesSummary AS (
    SELECT
        "VendorNo",
        "Brand",
        SUM("SalesQuantity") AS TotalSalesQuantity,
        SUM("SalesDollars") AS TotalSalesDollars,
        SUM("SalesPrice") AS TotalSalesPrice,
        SUM("ExciseTax") AS TotalExciseTax
    FROM sales
    GROUP BY "VendorNo", "Brand"
)
SELECT
    ps."VendorNumber",
    ps."VendorName",
    ps."Brand",
    ps."Description",
    ps."PurchasePrice",
    ps.ActualPrice,
    ps."Volume",
    ps.TotalPurchaseQuantity,
    ps.TotalPurchaseDollars,
    ss.TotalSalesQuantity,
    ss.TotalSalesDollars,
    ss.TotalSalesPrice,
    ss.TotalExciseTax,
    fs.FreightCost
FROM PurchaseSummary ps
LEFT JOIN SalesSummary ss
    ON ps."VendorNumber" = ss."VendorNo" AND ps."Brand" = ss."Brand"
LEFT JOIN FreightSummary fs
    ON ps."VendorNumber" = fs."VendorNumber"
ORDER BY ps.TotalPurchaseDollars DESC
""", conn)

# %%
vendor_sales_summary
# Out:
#        VendorNumber                   VendorName  Brand  \
# 0              1128  BROWN-FORMAN CORP             1233
# 1              4425        MARTIGNETTI COMPANIES   3405
# 2             17035  PERNOD RICARD USA             8068
# 3              3960  DIAGEO NORTH AMERICA INC      4261
# 4              3960  DIAGEO NORTH AMERICA INC      3545
# ...             ...                          ...    ...
# 10687          9815  WINE GROUP INC                8527
# 10688          8004  SAZERAC CO INC                5683
# 10689          3924  HEAVEN HILL DISTILLERIES      9123
# 10690          3960  DIAGEO NORTH AMERICA INC      6127
# 10691          7245  PROXIMO SPIRITS INC.          3065
#
#                        Description  PurchasePrice  actualprice Volume  \
# 0          Jack Daniels No 7 Black          26.27        36.99   1750
# 1            Tito's Handmade Vodka          23.19        28.99   1750
# 2                 Absolut 80 Proof          18.24        24.99   1750
# ...

# %% [markdown]
#  thi squery generates a vendor wise sales and purchase summary which is valid for:
#
# # performance optimization :
#
# * the query involves heavy joins and aggregation on large data set like sales and purchase
# * storing pre aggregate results avoids repeated expensive computation
# * help in analyzing sales ,purchase and pricing for different vendors and brands
# * futurebenefits of storing this data for faster dashboard and reporting
# * isttead of running expensive queries each time dashboard can fetch data quickly from vendor_sales_summary

# %%
vendor_sales_summary.dtypes
# Out:
# VendorNumber               int64
# VendorName                object
# Brand                      int64
# Description               object
# PurchasePrice            float64
# actualprice              float64
# Volume                    object
# totalpurchasequantity    float64
# totalpurchasedollars     float64
# totalsalesquantity       float64
# totalsalesdollars        float64
# totalsalesprice          float64
# totalexcisetax           float64
# freightcost              float64
# dtype: object

# %%
vendor_sales_summary.isnull().sum()
# Out:
# VendorNumber               0
# VendorName                 0
# Brand                      0
# Description                0
# PurchasePrice              0
# actualprice                0
# Volume                     0
# totalpurchasequantity      0
# totalpurchasedollars       0
# totalsalesquantity       178
# totalsalesdollars        178
# totalsalesprice          178
# totalexcisetax           178
# freightcost                0
# dtype: int64

# %%
# vendor_sales_summary.reset_index(drop=True, inplace=True)
# vendor_sales_summary.columns = vendor_sales_summary.columns.str.strip()
vendor_sales_summary['VendorName'].unique()
# Out:
# array(['BROWN-FORMAN CORP          ', 'MARTIGNETTI COMPANIES',
#        'PERNOD RICARD USA          ', 'DIAGEO NORTH AMERICA INC   ',
#        'BACARDI USA INC            ', 'JIM BEAM BRANDS COMPANY    ',
#        'MAJESTIC FINE WINES        ', 'ULTRA BEVERAGE COMPANY LLP ',
#        'STOLI GROUP,(USA) LLC      ', 'PROXIMO SPIRITS INC.       ',
#        'MOET HENNESSY USA INC      ', 'CAMPARI AMERICA            ',
#        'SAZERAC CO INC             ', 'CONSTELLATION BRANDS INC   ',
#        'M S WALKER INC             ', 'SAZERAC NORTH AMERICA INC. ',
#        'PALM BAY INTERNATIONAL INC ', 'REMY COINTREAU USA INC     ',
#        'SIDNEY FRANK IMPORTING CO  ', 'E & J GALLO WINERY         ',
#        'WILLIAM GRANT & SONS INC   ', 'HEAVEN HILL DISTILLERIES   ',
#        'DISARONNO INTERNATIONAL LLC', 'EDRINGTON AMERICAS         ',
#        'CASTLE BRANDS CORP.        ', 'SOUTHERN WINE & SPIRITS NE ',
#        'STE MICHELLE WINE ESTATES  ', 'TRINCHERO FAMILY ESTATES   ',
# ...

# %%
vendor_sales_summary['Description'].unique()
# Out:
# array(['Jack Daniels No 7 Black', "Tito's Handmade Vodka",
#        'Absolut 80 Proof', ..., 'Crown Royal Apple',
#        'Concannon Glen Ellen Wh Zin', 'The Club Strawbry Margarita'],
#       dtype=object)

# %%
vendor_sales_summary['Volume']=vendor_sales_summary['Volume'].astype('float64')

# %%
vendor_sales_summary.fillna(0, inplace=True)

# %%
# Strip all column names to remove leading/trailing spaces
#vendor_sales_summary.columns = vendor_sales_summary.columns.str.strip()
vendor_sales_summary['VendorName'] = vendor_sales_summary['VendorName'].str.strip()  # remove whitespace from VendorName

# %%
print(vendor_sales_summary.columns)  # Check the exact column names

# If the columns are correct, use them directly. Otherwise, adjust as needed.
vendor_sales_summary['gross_profit'] = vendor_sales_summary['totalsalesdollars'] - vendor_sales_summary['totalpurchasedollars']
# Out:
# Index(['VendorNumber', 'VendorName', 'Brand', 'Description', 'PurchasePrice',
#        'actualprice', 'Volume', 'totalpurchasequantity',
#        'totalpurchasedollars', 'totalsalesquantity', 'totalsalesdollars',
#        'totalsalesprice', 'totalexcisetax', 'freightcost'],
#       dtype='object')

# %%
vendor_sales_summary['gross_profit'].min()
# Out:
# np.float64(-52002.78000000003)

# %%
vendor_sales_summary['profitMargin']= (vendor_sales_summary['gross_profit'] / vendor_sales_summary['totalpurchasedollars']) * 100

# %%
vendor_sales_summary['StockTurnover'] = vendor_sales_summary['totalsalesquantity'] / vendor_sales_summary['totalpurchasequantity']

# %%
vendor_sales_summary['salespurchaseratio']= vendor_sales_summary['totalsalesdollars'] / vendor_sales_summary['totalpurchasedollars']

# %%
# To get a DBAPI cursor from a SQLAlchemy engine:
with conn.connect() as connection:
	cursor = connection.connection.cursor()
	# Now you can use cursor as needed

# %%
# If the cursor is closed or in a failed state, get a new one and rollback if needed
if connection.closed:
    connection = conn.connect()
try:
    connection.connection.rollback()  # rollback any failed transaction
except Exception:
    pass  # ignore if not needed

cursor = connection.connection.cursor()
cursor.execute("""
DROP TABLE IF EXISTS vendor_sales_summary;
CREATE TABLE vendor_sales_summary (
    VendorNumber INT,
    VendorName VARCHAR(100),
    Brand INT,
    Description VARCHAR(100),
    PurchasePrice DECIMAL(10,2),
    ActualPrice DECIMAL(10,2),
    Volume INT,
    
    TotalPurchaseQuantity INT,
    TotalPurchaseDollars DECIMAL(15,2),
    
    TotalSalesQuantity INT,
    TotalSalesDollars DECIMAL(15,2),
    TotalSalesPrice DECIMAL(15,2),
    TotalExciseTax DECIMAL(15,2),
    
    FreightCost DECIMAL(15,2),
    GrossProfit DECIMAL(15,2),
    ProfitMargin DECIMAL(15,2),
    StockTurnover DECIMAL(15,2),
    SalesToPurchaseRatio DECIMAL(15,2),
    
    PRIMARY KEY (VendorNumber, Brand)
);
""")
connection.connection.commit()

# %%
pd.read_sql_query("""select * from vendor_sales_summary;""", con=conn)
# Out:
# Empty DataFrame
# Columns: [vendornumber, vendorname, brand, description, purchaseprice, actualprice, volume, totalpurchasequantity, totalpurchasedollars, totalsalesquantity, totalsalesdollars, totalsalesprice, totalexcisetax, freightcost, grossprofit, profitmargin, stockturnover, salestopurchaseratio]
# Index: []

# %%
vendor_sales_summary.to_sql('vendor_sales_summary', con=conn, if_exists='replace', index=False)
# Out:
# 692
